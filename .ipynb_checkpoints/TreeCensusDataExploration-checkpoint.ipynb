# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
tree_census = pd.read_csv("C:/Users/bazar/Downloads/2015_Street_Tree_Census_-_Tree_Data_20240618.csv")
tree_census
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subs = tree_census[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subs
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum     NaN  NoDamage      NaN
# 1                        Quercus palustris     NaN    Damage   Stones
# ...

# %%
tree_census_subs.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# stump_diam         0
# curb_loc           0
# status             0
# health         31616
# spc_latin      31619
# steward       519438
# sidewalk       31616
# problems      457944
# root_stone         0
# root_grate         0
# root_other         0
# trunk_wire         0
# trnk_light         0
# trnk_other         0
# brch_light         0
# brch_shoe          0
# brch_other         0
# dtype: int64

# %%
tree_census_subs[tree_census_subs['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subs.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
tree_census_subs.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subs.hist(bins=60, figsize=(20, 10))
# Out:
# array([[<Axes: title={'center': 'tree_id'}>,
#         <Axes: title={'center': 'tree_dbh'}>],
#        [<Axes: title={'center': 'stump_diam'}>, <Axes: >]], dtype=object)

# %%
big_trees = tree_census_subs[tree_census_subs['stump_diam'] >50]

# %%
big_trees[['tree_id', 'stump_diam']].plot(kind='scatter', x='tree_id', y='stump_diam')
# Out:
# <Axes: xlabel='tree_id', ylabel='stump_diam'>

# %%
pd.DataFrame(tree_census_subs['spc_latin'].value_counts()).plot(kind='bar', figsize=(20, 10))
# Out:
# <Axes: xlabel='spc_latin'>

# %%
tree_census_subs['steward'].value_counts()
# Out:
# steward
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: count, dtype: int64

# %%
tree_census_subs['curb_loc'].value_counts()
# Out:
# curb_loc
# OnCurb            656896
# OffsetFromCurb     26892
# Name: count, dtype: int64

# %%
import numpy as np

# %%
series = [5, 9, 12, 27]
my_var = pd.Series(series)

# %%
my_var
# Out:
# 0     5
# 1     9
# 2    12
# 3    27
# dtype: int64

# %%
my_var[2] = 13
my_var[2]
# Out:
# 13

# %%
index = ['A', 'B', 'C', 'D']
var2 = pd.Series(series, index)
var2
# Out:
# A     5
# B     9
# C    12
# D    27
# dtype: int64

# %%
var2['B']
# Out:
# 9

# %%
cars = {'Tesla': 12, 'Mercedes': 42, 'BMW': 3}
var3 = pd.Series(cars)
var3['Tesla']
# Out:
# 12

# %%
from numpy.random import randn

# %%
data = randn(4, 3)  # Rows, Cols
rows = ['A', 'B', 'C', 'D']
cols = ['Monday', 'Tuesday', 'Friday']

# %%
#  Create DataFrame
df = pd.DataFrame(data, rows, cols)

# %%
df
# Out:
#      Monday   Tuesday    Friday
# A -0.285327 -1.980133 -1.258915
# B -0.251058 -1.175933 -1.529737
# C  0.501300 -1.187423  0.562071
# D  1.800221 -0.870809  0.868822

# %%
#  Import csv file
df = pd.read_csv("C:/Users/bazar/Downloads/train.csv")
#  Pull out rows
df.loc[[0, 5]]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
# 5            6         0       3         Moran, Mr. James  male   NaN      0
#
#    Parch     Ticket    Fare Cabin Embarked
# 0      0  A/5 21171  7.2500   NaN        S
# 5      0     330877  8.4583   NaN        Q

# %%
# grab last 5 rows
df.tail()
# grab first 5 rows
df.head()
# get info about df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.iloc[:, 3]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Cabin'].value_counts(dropna=False)
# Out:
# Cabin
# NaN            687
# C23 C25 C27      4
# G6               4
# B96 B98          4
# C22 C26          3
#               ...
# E34              1
# C7               1
# C54              1
# E36              1
# C148             1
# Name: count, Length: 148, dtype: int64

# %%
df['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
